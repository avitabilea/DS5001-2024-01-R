# %% [markdown]
# # Textbook Language Model
#
# ```yaml
# Course:  DS 5001
# Module:  03 Lab
# Topic:   Textbook Language Model
# Author:  R.C. Alvarado
# Date:    31 January 2023
# ```
#
# **Purpose**: Demonstrates use of simple langauge model based on Berkeley restaurant data (from Jurafsky and Martin).

# %% [markdown]
# ## Set Up

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Make the Data

# %% [markdown]
# We convert these three tables into Pandas dataframes and use them to predict and generate sentences.
#
# ![](lm-data.png)

# %% [markdown]
# First, we create the table of unigrams and their frrequencies, i.e. the priors or marginals of a bigram model.
#
# Note that this counts are relative to the entire corpus, not just the subset represented in the bigram table. So, we can't compute the probabilities of the unigrams.

# %%
data1 = dict(
    w0 = "i want to eat chinese food lunch spend".split(),
    n = [2533, 927, 2417, 746, 158, 1093, 341, 278]
)

# %%
df1 = pd.DataFrame(data1).set_index(['w0'])
df1.n = df1.n.astype('int')

# %% [markdown]
# Since we will want to use unigram probabilities for our model, we will estimate the number of tokens in the corpus. We will chose $50000$, based on the data found in [The Berkeley Restaurant Project (BeRP) Transcripts](https://github.com/wooters/berp-trans/). (We sum the counts in the `wordhist.txt` file and round down, since the data in the repo contain higher word counts for our words.)

# %%
C = 50000

# %%
df1['p'] = df1.n / C
df1['i'] = np.log2(1/df1.p)

# %%
df1
# Out:
#             n        p         i
# w0
# i        2533  0.05066  4.303009
# want      927  0.01854  5.753215
# to       2417  0.04834  4.370639
# eat       746  0.01492  6.066609
# chinese   158  0.00316  8.305860
# food     1093  0.02186  5.515563
# lunch     341  0.00682  7.196013
# spend     278  0.00556  7.490699

# %% [markdown]
# Next, we create a table joint probabilities that will be the basis for our bigram model.

# %%
data2 = [row.split(", ") for row in """
i, i, 5
i, want, 837
i, eat, 9
i, spend, 2
want, i, 2
want, to, 608
want, eat, 1
want, chinese, 6
want, food, 6
want, lunch, 5
want, spend, 1
to, i, 2
to, to, 4
to, eat, 686
to, chinese, 2
to, lunch, 6
to, spend, 211
eat, to, 2
eat, chinese, 16
eat, food, 2
eat, lunch, 42
chinese, i, 1
chinese, food, 82
chinese, lunch, 1
food, i, 15
food, to, 15
food, chinese, 1
food, food, 4
lunch, i, 2
lunch, food, 1
spend, i, 1
spend, to, 1
""".split("\n")[1:-1]]

# %%
df2 = pd.DataFrame(data2, columns = ['w0', 'w1', 'n']).set_index(['w0','w1'])
df2.n = df2.n.astype('int')

# %%
df2.sort_values('n', ascending=False)
# Out:
#                    n
# w0      w1
# i       want     837
# to      eat      686
# want    to       608
# to      spend    211
# chinese food      82
# eat     lunch     42
#         chinese   16
# food    to        15
#         i         15
# i       eat        9
# want    chinese    6
#         food       6
# to      lunch      6
# i       i          5
# want    lunch      5
# food    food       4
# to      to         4
#         chinese    2
#         i          2
# eat     to         2
#         food       2
# lunch   i          2
# want    i          2
# i       spend      2
# spend   i          1
# lunch   food       1
# chinese lunch      1
# food    chinese    1
# want    eat        1
# chinese i          1
# want    spend      1
# spend   to         1

# %%
df2.unstack(fill_value=0).style.background_gradient(cmap='YlGnBu', axis=None)
# Out:
# <style type="text/css">
# #T_b7d2f_row0_col0, #T_b7d2f_row0_col1, #T_b7d2f_row0_col3, #T_b7d2f_row0_col4, #T_b7d2f_row0_col5, #T_b7d2f_row0_col6, #T_b7d2f_row0_col7, #T_b7d2f_row1_col1, #T_b7d2f_row1_col2, #T_b7d2f_row1_col3, #T_b7d2f_row1_col5, #T_b7d2f_row1_col6, #T_b7d2f_row1_col7, #T_b7d2f_row2_col0, #T_b7d2f_row2_col1, #T_b7d2f_row2_col4, #T_b7d2f_row2_col5, #T_b7d2f_row2_col7, #T_b7d2f_row3_col0, #T_b7d2f_row3_col2, #T_b7d2f_row3_col4, #T_b7d2f_row3_col5, #T_b7d2f_row3_col6, #T_b7d2f_row4_col0, #T_b7d2f_row4_col1, #T_b7d2f_row4_col2, #T_b7d2f_row4_col3, #T_b7d2f_row4_col4, #T_b7d2f_row4_col5, #T_b7d2f_row4_col6, #T_b7d2f_row4_col7, #T_b7d2f_row5_col0, #T_b7d2f_row5_col1, #T_b7d2f_row5_col2, #T_b7d2f_row5_col3, #T_b7d2f_row5_col4, #T_b7d2f_row5_col5, #T_b7d2f_row5_col6, #T_b7d2f_row5_col7, #T_b7d2f_row6_col0, #T_b7d2f_row6_col2, #T_b7d2f_row6_col3, #T_b7d2f_row6_col7, #T_b7d2f_row7_col1, #T_b7d2f_row7_col3, #T_b7d2f_row7_col5, #T_b7d2f_row7_col7 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_b7d2f_row0_col2 {
#   background-color: #f1faba;
#   color: #000000;
# }
# #T_b7d2f_row1_col0, #T_b7d2f_row2_col3, #T_b7d2f_row2_col6 {
#   background-color: #fdfed4;
#   color: #000000;
# }
# #T_b7d2f_row1_col4 {
#   background-color: #f8fcca;
#   color: #000000;
# }
# #T_b7d2f_row2_col2, #T_b7d2f_row3_col3, #T_b7d2f_row6_col4, #T_b7d2f_row6_col6, #T_b7d2f_row7_col0, #T_b7d2f_row7_col2, #T_b7d2f_row7_col4 {
#   background-color: #feffd8;
#   color: #000000;
# }
# #T_b7d2f_row3_col1 {
#   background-color: #feffd6;
#   color: #000000;
# }
# #T_b7d2f_row3_col7 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_b7d2f_row6_col1 {
#   background-color: #24479d;
#   color: #f1f1f1;
# }
# #T_b7d2f_row6_col5 {
#   background-color: #c6e9b4;
#   color: #000000;
# }
# #T_b7d2f_row7_col6 {
#   background-color: #2168ad;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b7d2f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b7d2f_level0_col0" class="col_heading level0 col0" colspan="8">n</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >w1</th>
#       <th id="T_b7d2f_level1_col0" class="col_heading level1 col0" >chinese</th>
#       <th id="T_b7d2f_level1_col1" class="col_heading level1 col1" >eat</th>
#       <th id="T_b7d2f_level1_col2" class="col_heading level1 col2" >food</th>
#       <th id="T_b7d2f_level1_col3" class="col_heading level1 col3" >i</th>
#       <th id="T_b7d2f_level1_col4" class="col_heading level1 col4" >lunch</th>
#       <th id="T_b7d2f_level1_col5" class="col_heading level1 col5" >spend</th>
#       <th id="T_b7d2f_level1_col6" class="col_heading level1 col6" >to</th>
#       <th id="T_b7d2f_level1_col7" class="col_heading level1 col7" >want</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >w0</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b7d2f_level0_row0" class="row_heading level0 row0" >chinese</th>
#       <td id="T_b7d2f_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_b7d2f_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_b7d2f_row0_col2" class="data row0 col2" >82</td>
#       <td id="T_b7d2f_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_b7d2f_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_b7d2f_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_b7d2f_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_b7d2f_row0_col7" class="data row0 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_b7d2f_level0_row1" class="row_heading level0 row1" >eat</th>
#       <td id="T_b7d2f_row1_col0" class="data row1 col0" >16</td>
#       <td id="T_b7d2f_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_b7d2f_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_b7d2f_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_b7d2f_row1_col4" class="data row1 col4" >42</td>
#       <td id="T_b7d2f_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_b7d2f_row1_col6" class="data row1 col6" >2</td>
#       <td id="T_b7d2f_row1_col7" class="data row1 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_b7d2f_level0_row2" class="row_heading level0 row2" >food</th>
#       <td id="T_b7d2f_row2_col0" class="data row2 col0" >1</td>
#       <td id="T_b7d2f_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_b7d2f_row2_col2" class="data row2 col2" >4</td>
#       <td id="T_b7d2f_row2_col3" class="data row2 col3" >15</td>
#       <td id="T_b7d2f_row2_col4" class="data row2 col4" >0</td>
#       <td id="T_b7d2f_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_b7d2f_row2_col6" class="data row2 col6" >15</td>
#       <td id="T_b7d2f_row2_col7" class="data row2 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_b7d2f_level0_row3" class="row_heading level0 row3" >i</th>
#       <td id="T_b7d2f_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_b7d2f_row3_col1" class="data row3 col1" >9</td>
#       <td id="T_b7d2f_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_b7d2f_row3_col3" class="data row3 col3" >5</td>
#       <td id="T_b7d2f_row3_col4" class="data row3 col4" >0</td>
#       <td id="T_b7d2f_row3_col5" class="data row3 col5" >2</td>
#       <td id="T_b7d2f_row3_col6" class="data row3 col6" >0</td>
#       <td id="T_b7d2f_row3_col7" class="data row3 col7" >837</td>
#     </tr>
#     <tr>
#       <th id="T_b7d2f_level0_row4" class="row_heading level0 row4" >lunch</th>
#       <td id="T_b7d2f_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_b7d2f_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_b7d2f_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_b7d2f_row4_col3" class="data row4 col3" >2</td>
#       <td id="T_b7d2f_row4_col4" class="data row4 col4" >0</td>
#       <td id="T_b7d2f_row4_col5" class="data row4 col5" >0</td>
#       <td id="T_b7d2f_row4_col6" class="data row4 col6" >0</td>
#       <td id="T_b7d2f_row4_col7" class="data row4 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_b7d2f_level0_row5" class="row_heading level0 row5" >spend</th>
#       <td id="T_b7d2f_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_b7d2f_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_b7d2f_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_b7d2f_row5_col3" class="data row5 col3" >1</td>
#       <td id="T_b7d2f_row5_col4" class="data row5 col4" >0</td>
#       <td id="T_b7d2f_row5_col5" class="data row5 col5" >0</td>
#       <td id="T_b7d2f_row5_col6" class="data row5 col6" >1</td>
#       <td id="T_b7d2f_row5_col7" class="data row5 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_b7d2f_level0_row6" class="row_heading level0 row6" >to</th>
#       <td id="T_b7d2f_row6_col0" class="data row6 col0" >2</td>
#       <td id="T_b7d2f_row6_col1" class="data row6 col1" >686</td>
#       <td id="T_b7d2f_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_b7d2f_row6_col3" class="data row6 col3" >2</td>
#       <td id="T_b7d2f_row6_col4" class="data row6 col4" >6</td>
#       <td id="T_b7d2f_row6_col5" class="data row6 col5" >211</td>
#       <td id="T_b7d2f_row6_col6" class="data row6 col6" >4</td>
#       <td id="T_b7d2f_row6_col7" class="data row6 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_b7d2f_level0_row7" class="row_heading level0 row7" >want</th>
#       <td id="T_b7d2f_row7_col0" class="data row7 col0" >6</td>
#       <td id="T_b7d2f_row7_col1" class="data row7 col1" >1</td>
#       <td id="T_b7d2f_row7_col2" class="data row7 col2" >6</td>
#       <td id="T_b7d2f_row7_col3" class="data row7 col3" >2</td>
#       <td id="T_b7d2f_row7_col4" class="data row7 col4" >5</td>
#       <td id="T_b7d2f_row7_col5" class="data row7 col5" >1</td>
#       <td id="T_b7d2f_row7_col6" class="data row7 col6" >608</td>
#       <td id="T_b7d2f_row7_col7" class="data row7 col7" >0</td>
#     </tr>
#   </tbody>
# </ta

# %% [markdown]
# Next, we compute conditional probabilities $p$ with the formula $p(B|A) = \large \frac{P(A,B)}{P(A)}$ converted to $\large \frac{C(A,B)}{C(A)}$.
#
# We also compute the information $i$ for each $p$. This will allow use to compute perplexity $pp$ easily.
#
# Note that information $i$ is just the negative of the log probability of the event, so we can use this to compute the log probability of sentences later.

# %%
df2['p'] = df2.n / df1.n
df2['i'] = np.log2(1/df2.p)

# %%
df2.sort_values('p', ascending=False).style.background_gradient(cmap='YlGnBu')
# Out:
# <style type="text/css">
# #T_e0cb8_row0_col0 {
#   background-color: #2168ad;
#   color: #f1f1f1;
# }
# #T_e0cb8_row0_col1, #T_e0cb8_row2_col0, #T_e0cb8_row31_col2 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_e0cb8_row0_col2, #T_e0cb8_row11_col0, #T_e0cb8_row12_col0, #T_e0cb8_row13_col0, #T_e0cb8_row15_col0, #T_e0cb8_row16_col0, #T_e0cb8_row17_col0, #T_e0cb8_row19_col0, #T_e0cb8_row19_col1, #T_e0cb8_row20_col0, #T_e0cb8_row20_col1, #T_e0cb8_row21_col0, #T_e0cb8_row21_col1, #T_e0cb8_row22_col1, #T_e0cb8_row23_col0, #T_e0cb8_row23_col1, #T_e0cb8_row24_col1, #T_e0cb8_row25_col0, #T_e0cb8_row25_col1, #T_e0cb8_row26_col0, #T_e0cb8_row26_col1, #T_e0cb8_row27_col0, #T_e0cb8_row27_col1, #T_e0cb8_row28_col0, #T_e0cb8_row28_col1, #T_e0cb8_row29_col0, #T_e0cb8_row29_col1, #T_e0cb8_row30_col0, #T_e0cb8_row30_col1, #T_e0cb8_row31_col0, #T_e0cb8_row31_col1 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_e0cb8_row1_col0 {
#   background-color: #f1fabb;
#   color: #000000;
# }
# #T_e0cb8_row1_col1 {
#   background-color: #2350a1;
#   color: #f1f1f1;
# }
# #T_e0cb8_row1_col2, #T_e0cb8_row6_col1 {
#   background-color: #fafdcf;
#   color: #000000;
# }
# #T_e0cb8_row2_col1 {
#   background-color: #40b5c4;
#   color: #f1f1f1;
# }
# #T_e0cb8_row2_col2 {
#   background-color: #f0f9b8;
#   color: #000000;
# }
# #T_e0cb8_row3_col0, #T_e0cb8_row20_col2, #T_e0cb8_row21_col2 {
#   background-color: #24479d;
#   color: #f1f1f1;
# }
# #T_e0cb8_row3_col1 {
#   background-color: #63c3bf;
#   color: #000000;
# }
# #T_e0cb8_row3_col2 {
#   background-color: #edf8b2;
#   color: #000000;
# }
# #T_e0cb8_row4_col0 {
#   background-color: #c6e9b4;
#   color: #000000;
# }
# #T_e0cb8_row4_col1 {
#   background-color: #ecf7b1;
#   color: #000000;
# }
# #T_e0cb8_row4_col2 {
#   background-color: #abdeb7;
#   color: #000000;
# }
# #T_e0cb8_row5_col0 {
#   background-color: #f8fcca;
#   color: #000000;
# }
# #T_e0cb8_row5_col1 {
#   background-color: #f3fabf;
#   color: #000000;
# }
# #T_e0cb8_row5_col2 {
#   background-color: #85cfba;
#   color: #000000;
# }
# #T_e0cb8_row6_col0, #T_e0cb8_row7_col0, #T_e0cb8_row8_col0 {
#   background-color: #fdfed4;
#   color: #000000;
# }
# #T_e0cb8_row6_col2 {
#   background-color: #3eb3c4;
#   color: #f1f1f1;
# }
# #T_e0cb8_row7_col1, #T_e0cb8_row8_col1 {
#   background-color: #fcfed3;
#   color: #000000;
# }
# #T_e0cb8_row7_col2, #T_e0cb8_row8_col2 {
#   background-color: #2b9fc2;
#   color: #f1f1f1;
# }
# #T_e0cb8_row9_col0, #T_e0cb8_row10_col0, #T_e0cb8_row13_col1, #T_e0cb8_row14_col0, #T_e0cb8_row14_col1, #T_e0cb8_row15_col1, #T_e0cb8_row16_col1, #T_e0cb8_row17_col1, #T_e0cb8_row18_col1, #T_e0cb8_row22_col0, #T_e0cb8_row24_col0 {
#   background-color: #feffd8;
#   color: #000000;
# }
# #T_e0cb8_row9_col1, #T_e0cb8_row10_col1, #T_e0cb8_row11_col1, #T_e0cb8_row12_col1, #T_e0cb8_row18_col0 {
#   background-color: #feffd6;
#   color: #000000;
# }
# #T_e0cb8_row9_col2, #T_e0cb8_row10_col2 {
#   background-color: #1f78b4;
#   color: #f1f1f1;
# }
# #T_e0cb8_row11_col2, #T_e0cb8_row12_col2 {
#   background-color: #2076b3;
#   color: #f1f1f1;
# }
# #T_e0cb8_row13_col2 {
#   background-color: #2072b1;
#   color: #f1f1f1;
# }
# #T_e0cb8_row14_col2 {
#   background-color: #216daf;
#   color: #f1f1f1;
# }
# #T_e0cb8_row15_col2 {
#   background-color: #2356a4;
#   color: #f1f1f1;
# }
# #T_e0cb8_row16_col2, #T_e0cb8_row17_col2, #T_e0cb8_row18_col2 {
#   background-color: #2355a4;
#   color: #f1f1f1;
# }
# #T_e0cb8_row19_col2 {
#   background-color: #234b9f;
#   color: #f1f1f1;
# }
# #T_e0cb8_row22_col2 {
#   background-color: #24439b;
#   color: #f1f1f1;
# }
# #T_e0cb8_row23_col2 {
#   background-color: #243c98;
#   color: #f1f1f1;
# }
# #T_e0cb8_row24_col2 {
#   background-color: #253795;
#   color: #f1f1f1;
# }
# #T_e0cb8_row25_col2 {
#   background-color: #21318d;
#   color: #f1f1f1;
# }
# #T_e0cb8_row26_col2, #T_e0cb8_row27_col2 {
#   background-color: #12256d;
#   color: #f1f1f1;
# }
# #T_e0cb8_row28_col2 {
#   background-color: #0d2161;
#   color: #f1f1f1;
# }
# #T_e0cb8_row29_col2, #T_e0cb8_row30_col2 {
#   background-color: #091e5a;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e0cb8">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e0cb8_level0_col0" class="col_heading level0 col0" >n</th>
#       <th id="T_e0cb8_level0_col1" class="col_heading level0 col1" >p</th>
#       <th id="T_e0cb8_level0_col2" class="col_heading level0 col2" >i</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >w0</th>
#       <th class="index_name level1" >w1</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e0cb8_level0_row0" class="row_heading level0 row0" >want</th>
#       <th id="T_e0cb8_level1_row0" class="row_heading level1 row0" >to</th>
#       <td id="T_e0cb8_row0_col0" class="data row0 col0" >608</td>
#       <td id="T_e0cb8_row0_col1" class="data row0 col1" >0.655879</td>
#       <td id="T_e0cb8_row0_col2" class="data row0 col2" >0.608498</td>
#     </tr>
#     <tr>
#       <th id="T_e0cb8_level0_row1" class="row_heading level0 row1" >chinese</th>
#       <th id="T_e0cb8_level1_row1" class="row_heading level1 row1" >food</th>
#       <td id="T_e0cb8_row1_col0" class="data row1 col0" >82</td>
#       <td id="T_e0cb8_row1_col1" class="data row1 col1" >0.518987</td>
#       <td id="T_e0cb8_row1_col2" class="data row1 col2" >0.946229</td>
#     </tr>
#     <tr>
#       <th id="T_e0cb8_level0_row2" class="row_heading level0 row2" >i</th>
#       <th id="T_e0cb8_level1_row2" class="row_heading level1 row2" >want</th>
#       <td id="T_e0cb8_row2_col0" class="data row2 col0" >837</td>
#       <td id="T_e0cb8_row2_col1" class="data row2 col1" >0.330438</td>
#       <td id="T_e0cb8_row2_col2" class="data row2 col2" >1.597548</td>
#     </tr>
#     <tr>
#       <th id="T_e0cb8_level0_row3" class="row_heading level0 row3" rowspan="2">to</th>
#       <th id="T_e0cb8_level1_row3" class="row_heading level1 row3" >eat</th>
#       <td id="T_e0cb8_row3_col0" class="data row3 col0" >686</td>
#       <td id="T_e0cb8_row3_col1" class="data row3 col1" >0.283823</td>
#       <td id="T_e0cb8_row3_col2" class="data row3 col2" >1.816937</td>
#     </tr>
#     <tr>
#       <th id="T_e0cb8_level1_row4" class="row_heading level1 row4" >spend</th>
#       <td id="T_e0cb8_row4_col0" class="data row4 col0" >211</td>
#       <td id="T_e0cb8_row4_col1" class="data row4 col1" >0.087298</td>
#       <td id="T_e0cb8_row4_col2" class="data row4 col2" >3.517903</td>
#     </tr>
#     <tr>
#       <th id="T_e0cb8_level0_row5" class="row_heading level0 row5" rowspan="2">eat</th>
#       <th id="T_e0cb8_level1_row5" class="row_heading level1 row5" >lunch</th>
#       <td id="T_e0cb8_row5_col0" class="data row5 col0" >42</td>
#       <td id="T_e0cb8_row5_col1" class="data row5 col1" >0.056300</td>
#       <td id="T_e0cb8_row5_col2" class="data row5 col2" >4.150714</td>
#     </tr>
#     <tr>
#       <th id="T_e0cb8_level1_row6" class="row_heading level1 row6" >chinese</th>
#       <td id="T_e0cb8_row6_col0" class="data row6 col0" >16</td>
#       <td id="T_e0cb8_row6_col1" class="data row6 col1" >0.021448</td>
#       <td id="T_e0cb8_row6_col2" class="data row6 col2" >5.543032</td>
#     </tr>
#     <tr>
#       <th id="T_e0cb8_level0_row7" class="row_heading level0 row7" rowspan="2">food</th>
#       <th id="T_e0cb8_level1_row7" class="row_heading level1 row7" >to</th>
#       <td id="T_e0cb8_row7_col0" class="data row7 col0" >15</td>
#       <td id="T_e0cb8_row7_col1" class="data row7 col1" >0.013724</td>
#       <td id="T_e0cb8_row7_col2" class="data row7 col2" >6.187187</td>
#     </tr>
#     <tr>
#       <th id="T_e0cb8_level1_row8" class="row_heading level1 row8" >i</th>
#       <td id="T_e0cb8_row8_col0" class="data row8 col0" >15</td>
#       <td id="T_e0cb8_row8_col1" class="data row8 col1" >0.013724</td>
#       <td id="T_e0cb8_row8_col2" class="data row8 col2" >6.187187</td>
#     </tr>
#     <tr>
#       <th id="T_e0cb8_level0_row9" class="row_heading level0 row9" rowspan="2">want</th>
#       <th id="T_e0cb8_level1_row9" class="row_heading level1 row9" >chinese</th>
#       <td id="T_e0cb8_row9_col0" class="data row9 col0" >6</td>
#       <td id="T_e0cb8_row9_col1" class="d

# %% [markdown]
# We convert a selection from the narrow table into a wide one, projecting the second index feature `w1` onto the second axis.
#
# This is strictly not necessary, but it is convenient for certain computations and it is visually appealing.

# %%
df3 = df2.p.unstack(fill_value=0)

# %%
df3.style.background_gradient(cmap='YlGnBu', axis=None)
# Out:
# <style type="text/css">
# #T_db072_row0_col0, #T_db072_row0_col1, #T_db072_row0_col5, #T_db072_row0_col6, #T_db072_row0_col7, #T_db072_row1_col1, #T_db072_row1_col3, #T_db072_row1_col5, #T_db072_row1_col7, #T_db072_row2_col0, #T_db072_row2_col1, #T_db072_row2_col4, #T_db072_row2_col5, #T_db072_row2_col7, #T_db072_row3_col0, #T_db072_row3_col2, #T_db072_row3_col3, #T_db072_row3_col4, #T_db072_row3_col5, #T_db072_row3_col6, #T_db072_row4_col0, #T_db072_row4_col1, #T_db072_row4_col4, #T_db072_row4_col5, #T_db072_row4_col6, #T_db072_row4_col7, #T_db072_row5_col0, #T_db072_row5_col1, #T_db072_row5_col2, #T_db072_row5_col4, #T_db072_row5_col5, #T_db072_row5_col7, #T_db072_row6_col0, #T_db072_row6_col2, #T_db072_row6_col3, #T_db072_row6_col4, #T_db072_row6_col6, #T_db072_row6_col7, #T_db072_row7_col1, #T_db072_row7_col3, #T_db072_row7_col5, #T_db072_row7_col7 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_db072_row0_col2 {
#   background-color: #2350a1;
#   color: #f1f1f1;
# }
# #T_db072_row0_col3, #T_db072_row0_col4, #T_db072_row4_col3, #T_db072_row7_col0, #T_db072_row7_col2, #T_db072_row7_col4 {
#   background-color: #feffd6;
#   color: #000000;
# }
# #T_db072_row1_col0 {
#   background-color: #fafdcf;
#   color: #000000;
# }
# #T_db072_row1_col2, #T_db072_row1_col6, #T_db072_row2_col2, #T_db072_row3_col1, #T_db072_row4_col2, #T_db072_row5_col3, #T_db072_row5_col6 {
#   background-color: #feffd8;
#   color: #000000;
# }
# #T_db072_row1_col4 {
#   background-color: #f3fabf;
#   color: #000000;
# }
# #T_db072_row2_col3, #T_db072_row2_col6 {
#   background-color: #fcfed3;
#   color: #000000;
# }
# #T_db072_row3_col7 {
#   background-color: #40b5c4;
#   color: #f1f1f1;
# }
# #T_db072_row6_col1 {
#   background-color: #63c3bf;
#   color: #000000;
# }
# #T_db072_row6_col5 {
#   background-color: #eaf7b1;
#   color: #000000;
# }
# #T_db072_row7_col6 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_db072">
#   <thead>
#     <tr>
#       <th class="index_name level0" >w1</th>
#       <th id="T_db072_level0_col0" class="col_heading level0 col0" >chinese</th>
#       <th id="T_db072_level0_col1" class="col_heading level0 col1" >eat</th>
#       <th id="T_db072_level0_col2" class="col_heading level0 col2" >food</th>
#       <th id="T_db072_level0_col3" class="col_heading level0 col3" >i</th>
#       <th id="T_db072_level0_col4" class="col_heading level0 col4" >lunch</th>
#       <th id="T_db072_level0_col5" class="col_heading level0 col5" >spend</th>
#       <th id="T_db072_level0_col6" class="col_heading level0 col6" >to</th>
#       <th id="T_db072_level0_col7" class="col_heading level0 col7" >want</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >w0</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_db072_level0_row0" class="row_heading level0 row0" >chinese</th>
#       <td id="T_db072_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_db072_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_db072_row0_col2" class="data row0 col2" >0.518987</td>
#       <td id="T_db072_row0_col3" class="data row0 col3" >0.006329</td>
#       <td id="T_db072_row0_col4" class="data row0 col4" >0.006329</td>
#       <td id="T_db072_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_db072_row0_col6" class="data row0 col6" >0.000000</td>
#       <td id="T_db072_row0_col7" class="data row0 col7" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_db072_level0_row1" class="row_heading level0 row1" >eat</th>
#       <td id="T_db072_row1_col0" class="data row1 col0" >0.021448</td>
#       <td id="T_db072_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_db072_row1_col2" class="data row1 col2" >0.002681</td>
#       <td id="T_db072_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_db072_row1_col4" class="data row1 col4" >0.056300</td>
#       <td id="T_db072_row1_col5" class="data row1 col5" >0.000000</td>
#       <td id="T_db072_row1_col6" class="data row1 col6" >0.002681</td>
#       <td id="T_db072_row1_col7" class="data row1 col7" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_db072_level0_row2" class="row_heading level0 row2" >food</th>
#       <td id="T_db072_row2_col0" class="data row2 col0" >0.000915</td>
#       <td id="T_db072_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_db072_row2_col2" class="data row2 col2" >0.003660</td>
#       <td id="T_db072_row2_col3" class="data row2 col3" >0.013724</td>
#       <td id="T_db072_row2_col4" class="data row2 col4" >0.000000</td>
#       <td id="T_db072_row2_col5" class="data row2 col5" >0.000000</td>
#       <td id="T_db072_row2_col6" class="data row2 col6" >0.013724</td>
#       <td id="T_db072_row2_col7" class="data row2 col7" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_db072_level0_row3" class="row_heading level0 row3" >i</th>
#       <td id="T_db072_row3_col0" class="data row3 col0" >0.000000</td>
#       <td id="T_db072_row3_col1" class="data row3 col1" >0.003553</td>
#       <td id="T_db072_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_db072_row3_col3" class="data row3 col3" >0.001974</td>
#       <td id="T_db072_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_db072_row3_col5" class="data row3 col5" >0.000790</td>
#       <td id="T_db072_row3_col6" class="data row3 col6" >0.000000</td>
#       <td id="T_db072_row3_col7" class="data row3 col7" >0.330438</td>
#     </tr>
#     <tr>
#       <th id="T_db072_level0_row4" class="row_heading level0 row4" >lunch</th>
#       <td id="T_db072_row4_col0" class="data row4 col0" >0.000000</td>
#       <td id="T_db072_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_db072_row4_col2" class="data row4 col2" >0.002933</td>
#       <td id="T_db072_row4_col3" class="data row4 col3" >0.005865</td>
#       <td id="T_db072_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_db072_row4_col5" class="data row4 col5" >0.000000</td>
#       <td id="T_db072_row4_col6" class="data row4 col6" >0.000000</td>
#       <td id="T_db072_row4_col7" class="data row4 col7" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_db072_level0_row5" class="row_heading level0 row5" >spend</th>
#       <td id="T_db072_row5_col0" class="data row5 col0" >0.000000</td>
#       <td id="T_db072_row5_col1" class="data row5 col1" >0.000000</td>
#       <td id="T_db072_row5_col2" class="data row5 col2" >0.000000</td>
#       <td id="T_db072_row5_col3" class="data row5 col3" >0.003597</td>
#       <td id="T_db072_row5_col4" class="data row5 col4" >0.000000</td>
#       <td id="T_db072_row5_col5" class="data row5 col5" >0.000000</td>
#       <td id="T_db072_row5_col6" class="data row5 col6" >0.003597</td>
#       <td id="T_db072_row5_col7" class="data row5 col7" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_db072_level0_row6" class="row_heading level0 row6" >to</th>
#       <td id="T_db072_row6_col0" class="data row6 col0" >0.000827</td>
#       <td id="T_db072_row6_col1" class="data row6 col1" >0.283823</td>
#       <td id="T_db072_row6_col2" class="data row6 col2" >0.000000</td>
#       <td id="T_db072_row6_col3" class="data row6 col3" >0.000827</td>
#       <td id="T_db072_row6_col4" class="data row6 col4" >0.002482</td>
#       <td id="T_db072_row6_col5" class="data row6 col5" >0.087298</td>
#       <td id="T_db072_row6_col6" class="data row6 col6" >0.001655</td>
#       <td id="T_db072_row6_col7" class="data row6 col7" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_db072_level0_row7" class="row_heading level0 row7" >want</th>
#       <td id="T_db072_row7_col0" class="data row7 col0" >0.006472</td>
#       <td id="T_db072_row7_col1" class="data row7 col1" >0.001079</td>
#       <td id="T_db072_row7_col2" class="data row7 col2" >0.006472</td>
#       <td id="T_db072_row7_col3" class="data

# %% [markdown]
# ## Apply the Model
#
# Now we generate sentences from the model and also compute their probabilities and perplexities.
#
# We also demonstrate the relationship between sum of log probability, mean information, and perplexity.

# %%
N = 20
M = 10
results = []

# Generate N sentences
for i in range(N):
    
    # Get a start word from the unigram list (since we don't have sentence boundaries in our bigram model
    start = df1.sample(weights='n')
    w0 = start.index[0]
    i = start.i.values[0] # This is why we needed to estimate the number of tokens in the corpus C
    
    # Initialize sentence feature lists
    W = [w0]
    I = [i]
    LP = [-i]
    
    # Select M words for each sentence
    for j in range(M - 1):
        w1 = df3.loc[w0].sample(weights=df3.loc[w0].values).index[0]
        i = df2.loc[(w0, w1), 'i']
        W.append(w1)
        I.append(i)
        LP.append(-i)
        w0 = w1

    # Compute sentence stats
    S = pd.DataFrame(dict(w=W, i=I, lp=LP)) # This is expensive; we'd do it differently at scale
    i_mean = S.i.mean()
    lp_sum = S.lp.sum()
    pp = 2**(i_mean)
    sent_str = ' '.join(W)
    
    # Append to results 
    results.append((sent_str, lp_sum, i_mean, pp))
    
# Put results in a dataframe
R = pd.DataFrame(results, columns=['sentence', 'logprob', 'i_mean', 'pp'])

# Keep only unique sentences, i.e. treat sentences as index values
sentence_counts = R.sentence.value_counts().to_frame('n')
R = R.drop_duplicates()
R = R.reset_index(drop=True).set_index('sentence')
R['n'] = sentence_counts

# Display results
R.sort_values('i_mean', ascending=True).style.background_gradient(cmap="YlGnBu")
# Out:
# <style type="text/css">
# #T_14b18_row0_col0, #T_14b18_row9_col3, #T_14b18_row14_col3, #T_14b18_row17_col1, #T_14b18_row17_col2 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_14b18_row0_col1, #T_14b18_row0_col2, #T_14b18_row0_col3, #T_14b18_row1_col3, #T_14b18_row2_col3, #T_14b18_row3_col3, #T_14b18_row4_col3, #T_14b18_row5_col3, #T_14b18_row6_col3, #T_14b18_row7_col3, #T_14b18_row8_col3, #T_14b18_row10_col3, #T_14b18_row11_col3, #T_14b18_row12_col3, #T_14b18_row13_col3, #T_14b18_row15_col3, #T_14b18_row16_col3, #T_14b18_row17_col0, #T_14b18_row17_col3 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_14b18_row1_col0 {
#   background-color: #12256d;
#   color: #f1f1f1;
# }
# #T_14b18_row1_col1 {
#   background-color: #f9fdcb;
#   color: #000000;
# }
# #T_14b18_row1_col2 {
#   background-color: #fdfed5;
#   color: #000000;
# }
# #T_14b18_row2_col0 {
#   background-color: #152772;
#   color: #f1f1f1;
# }
# #T_14b18_row2_col1 {
#   background-color: #f7fcc7;
#   color: #000000;
# }
# #T_14b18_row2_col2 {
#   background-color: #fcfed3;
#   color: #000000;
# }
# #T_14b18_row3_col0 {
#   background-color: #24409a;
#   color: #f1f1f1;
# }
# #T_14b18_row3_col1 {
#   background-color: #e2f4b2;
#   color: #000000;
# }
# #T_14b18_row3_col2 {
#   background-color: #f6fbc5;
#   color: #000000;
# }
# #T_14b18_row4_col0 {
#   background-color: #24439b;
#   color: #f1f1f1;
# }
# #T_14b18_row4_col1 {
#   background-color: #e0f3b2;
#   color: #000000;
# }
# #T_14b18_row4_col2, #T_14b18_row5_col2 {
#   background-color: #f5fbc4;
#   color: #000000;
# }
# #T_14b18_row5_col0 {
#   background-color: #24449c;
#   color: #f1f1f1;
# }
# #T_14b18_row5_col1 {
#   background-color: #dff2b2;
#   color: #000000;
# }
# #T_14b18_row6_col0, #T_14b18_row7_col0, #T_14b18_row8_col0 {
#   background-color: #234c9f;
#   color: #f1f1f1;
# }
# #T_14b18_row6_col1, #T_14b18_row7_col1, #T_14b18_row8_col1 {
#   background-color: #d7efb3;
#   color: #000000;
# }
# #T_14b18_row6_col2, #T_14b18_row7_col2, #T_14b18_row8_col2 {
#   background-color: #f4fbc0;
#   color: #000000;
# }
# #T_14b18_row9_col0 {
#   background-color: #2352a3;
#   color: #f1f1f1;
# }
# #T_14b18_row9_col1 {
#   background-color: #d1edb3;
#   color: #000000;
# }
# #T_14b18_row9_col2 {
#   background-color: #f3fabd;
#   color: #000000;
# }
# #T_14b18_row10_col0 {
#   background-color: #2259a6;
#   color: #f1f1f1;
# }
# #T_14b18_row10_col1 {
#   background-color: #cbebb4;
#   color: #000000;
# }
# #T_14b18_row10_col2 {
#   background-color: #f1faba;
#   color: #000000;
# }
# #T_14b18_row11_col0 {
#   background-color: #2165ab;
#   color: #f1f1f1;
# }
# #T_14b18_row11_col1 {
#   background-color: #bde5b5;
#   color: #000000;
# }
# #T_14b18_row11_col2 {
#   background-color: #eff9b5;
#   color: #000000;
# }
# #T_14b18_row12_col0 {
#   background-color: #2498c1;
#   color: #f1f1f1;
# }
# #T_14b18_row12_col1 {
#   background-color: #73c8bd;
#   color: #000000;
# }
# #T_14b18_row12_col2 {
#   background-color: #d6efb3;
#   color: #000000;
# }
# #T_14b18_row13_col0 {
#   background-color: #299dc1;
#   color: #f1f1f1;
# }
# #T_14b18_row13_col1 {
#   background-color: #6bc6be;
#   color: #000000;
# }
# #T_14b18_row13_col2, #T_14b18_row14_col2, #T_14b18_row15_col2 {
#   background-color: #d3eeb3;
#   color: #000000;
# }
# #T_14b18_row14_col0, #T_14b18_row15_col0 {
#   background-color: #2a9ec1;
#   color: #f1f1f1;
# }
# #T_14b18_row14_col1, #T_14b18_row15_col1 {
#   background-color: #69c5be;
#   color: #000000;
# }
# #T_14b18_row16_col0 {
#   background-color: #a7dcb7;
#   color: #000000;
# }
# #T_14b18_row16_col1 {
#   background-color: #2075b3;
#   color: #f1f1f1;
# }
# #T_14b18_row16_col2 {
#   background-color: #4cbac2;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_14b18">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_14b18_level0_col0" class="col_heading level0 col0" >logprob</th>
#       <th id="T_14b18_level0_col1" class="col_heading level0 col1" >i_mean</th>
#       <th id="T_14b18_level0_col2" class="col_heading level0 col2" >pp</th>
#       <th id="T_14b18_level0_col3" class="col_heading level0 col3" >n</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >sentence</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_14b18_level0_row0" class="row_heading level0 row0" >want to eat chinese food i want to eat lunch</th>
#       <td id="T_14b18_row0_col0" class="data row0 col0" >-29.028795</td>
#       <td id="T_14b18_row0_col1" class="data row0 col1" >2.902879</td>
#       <td id="T_14b18_row0_col2" class="data row0 col2" >7.479177</td>
#       <td id="T_14b18_row0_col3" class="data row0 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_14b18_level0_row1" class="row_heading level0 row1" >want to eat lunch i want to eat chinese food</th>
#       <td id="T_14b18_row1_col0" class="data row1 col0" >-30.255235</td>
#       <td id="T_14b18_row1_col1" class="data row1 col1" >3.025524</td>
#       <td id="T_14b18_row1_col2" class="data row1 col2" >8.142792</td>
#       <td id="T_14b18_row1_col3" class="data row1 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_14b18_level0_row2" class="row_heading level0 row2" >food i want to eat chinese food i want to</th>
#       <td id="T_14b18_row2_col0" class="data row2 col0" >-30.608226</td>
#       <td id="T_14b18_row2_col1" class="data row2 col1" >3.060823</td>
#       <td id="T_14b18_row2_col2" class="data row2 col2" >8.344482</td>
#       <td id="T_14b18_row2_col3" class="data row2 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_14b18_level0_row3" class="row_heading level0 row3" >lunch i want to eat chinese food i want to</th>
#       <td id="T_14b18_row3_col0" class="data row3 col0" >-33.515116</td>
#       <td id="T_14b18_row3_col1" class="data row3 col1" >3.351512</td>
#       <td id="T_14b18_row3_col2" class="data row3 col2" >10.207174</td>
#       <td id="T_14b18_row3_col3" class="data row3 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_14b18_level0_row4" class="row_heading level0 row4" >i want to eat lunch i want to spend i</th>
#       <td id="T_14b18_row4_col0" class="data row4 col0" >-33.733223</td>
#       <td id="T_14b18_row4_col1" class="data row4 col1" >3.373322</td>
#       <td id="T_14b18_row4_col2" class="data row4 col2" >10.362659</td>
#       <td id="T_14b18_row4_col3" class="data row4 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_14b18_level0_row5" class="row_heading level0 row5" >to spend i want to eat lunch i want to</th>
#       <td id="T_14b18_row5_col0" class="data row5 col0" >-33.800853</td>
#       <td id="T_14b18_row5_col1" class="data row5 col1" >3.380085</td>
#       <td id="T_14b18_row5_col2" class="data row5 col2" >10.411350</td>
#       <td id="T_14b18_row5_col3" class="data row5 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_14b18_level0_row6" class="row_heading level0 row6" >to eat lunch i want to eat chinese food i</th>
#       <td id="T_14b18_row6_col0" class="data row6 col0" >-34.451348</td>
#       <td id="T_14b18_row6_col1" class="data row6 col1" >3.445135</td>
#       <td id="T_14b18_row6_col2" class="data row6 col2" >10.891531</td>
#       <td id="T_14b18_row6_col3" class="data row6 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_14b18_level0_row7" class="row_heading level0 row7" >i want to eat chinese food to spend to eat</th>
#       <td id="T_14b18_row7_col0" class="data row7 col0" >-34.456220</td>
#       <td id="T_14b18_row7_col1" class="data row7 col1" >3.445622</td>
#       <td id="T_14b18_row7_col2" class="data row7 col2" >10.895209</td>
#       <td id="T_14b18_row7_col3" class="data row7 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_14b18_level0_row8" class="row_heading level0 row8" >food i want to eat food i want to eat</th>
#       <td id="T_14b18_row8_col0" class="data row8 col0" >-34.478934</td>
#       <td id="T_14b18_row8_col1" class="data row8 col1" >3.447893</td>
#       <td id="T_14b18_row8_col2" class="data row8 col2" >10.912376</td>
#       <td id="T_14b18_row8_col3" class="data row8 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_14b18_level0_row9" class="row_heading level0 row9" >to eat lunch i want to eat lunch i want</th>
#       <td id="T_14b18_row9_col0" class

# %% [markdown]
# ## Interpet Results

# %% [markdown]
# Compare mean `i` to the sum of log `p`. Notice they are identical when normalized by mean.

# %%
(R / R.mean()).sort_values('i_mean')[['i_mean','logprob']].reset_index().plot();

# %% [markdown]
# Compre perplexity `pp` to mean information `i`. Notice how perplexity amplifies the difference.

# %%
(R / R.mean()).sort_values('i_mean')[['i_mean','pp']].reset_index().plot();

# %% [markdown]
# So, we will use perplexity to measure of how well a model performs.

# %%
R.reset_index().set_index('sentence').sort_values('pp').i_mean.sort_values(ascending=False)\
    .plot.barh(figsize=(7,7), title="Generated Sentences Sorted by Perplexity");

# %% [markdown]
# Since perplexity looks something like squaring the error of our model (where mean information is interpreted as error), let's create a test feature that just squares mean information and compare to the other features.

# %%
R['test'] = R.i_mean**2

# %%
(R / R.mean()).sort_values('i_mean')[['i_mean', 'test','pp']].reset_index().plot();
